# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Importing Package(s)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the Dataset

# %%
borrower = pd.read_csv('../data/processed/Borrower.csv')
loan = pd.read_csv('../data/processed/Loan.csv')

# %% [markdown]
# ### Merging Loan and Borrower Dataset

# %%
df = loan.merge(borrower, on="memberId", how="left")
df.head()
# Out:
#     loanId  memberId        date            purpose  isJointApplication  \
# 0  1888978   2305095  12/10/2014  debtconsolidation                 0.0
# 1  1299695   2610493   9/15/2014  debtconsolidation                 0.0
# 2  1875016   2491679   9/11/2014  debtconsolidation                 0.0
# 3  1440478   2092798   4/22/2016    homeimprovement                 0.0
# 4  1124634   2633077    2/3/2016  debtconsolidation                 0.0
#
#    loanAmount       term  interestRate  monthlyPayment grade  ...  \
# 0     25190.0  60 months          6.25             490    E3  ...
# 1     21189.0  60 months         10.49             455    B3  ...
# 2     29908.0  60 months          9.11             622    B2  ...
# 3     13053.0  48 months         11.89             343    B3  ...
# 4     24613.0  60 months         15.13             587    A3  ...
#
#   lengthCreditHistory numTotalCreditLines numOpenCreditLines  \
# 0                   6                  11                9.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   loanId                    100000 non-null  int64
#  1   memberId                  100000 non-null  int64
#  2   date                      100000 non-null  object
#  3   purpose                   100000 non-null  object
#  4   isJointApplication        99029 non-null   float64
#  5   loanAmount                98994 non-null   float64
#  6   term                      98929 non-null   object
#  7   interestRate              100000 non-null  float64
#  8   monthlyPayment            100000 non-null  int64
#  9   grade                     100000 non-null  object
#  10  loanStatus                100000 non-null  object
#  11  residentialState          100000 non-null  object
#  12  yearsEmployment           100000 non-null  object
# ...
